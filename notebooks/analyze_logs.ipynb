# %%
import pandas as pd

df = pd.read_csv("../benchmark_log.csv", sep=",")

df.head()
# Out:
#                                                                                                                                        Timestamp  \
# 2025-01-06 10:56:22 49.796663 44.739867 0.006312 0.111757 13.410858 120.0 55.790276 70.437044  The video features a person seated at a desk i...
#
#                                                                                                Total_Runtime  \
# 2025-01-06 10:56:22 49.796663 44.739867 0.006312 0.111757 13.410858 120.0 55.790276 70.437044      66.221434
#
#                                                                                                Model_Runtime  \
# 2025-01-06 10:56:22 49.796663 44.739867 0.006312 0.111757 13.410858 120.0 55.790276 70.437044      60.888193
#
#                                                                                                Extra_Runtime  \
# 2025-01-06 10:56:22 49.796663 44.739867 0.006312 0.111757 13.410858 120.0 55.790276 70.437044       0.006938
#
# ...
